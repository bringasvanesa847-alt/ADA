# %% [markdown]
# # PRACTICA 2
#
# ### Eliminacion de duplicados en JSON usando C++
# Este programa elimina registros duplicados basandose en el campo transaction_id, conservando unicamente la primera aparicion.
#
# ### Descripcion
# El algoritmo recorre los registros del archivo JSON y utiliza un conjunto (unordered_set) para almacenar los  identificadores ya vistos. Si un identificador no ha sido procesado, se agrega al resultado.

# %%
# %%bash
# sudo apt update
# sudo apt install -y nlohmann-json3-dev

# %%
# %%bash
# g++ SOLUCION_DE_PROBLEMAS_EN_C.cpp -O2 -o dedup && ./dedup
# Out:
# cc1plus: fatal error: remove_duplicates.cpp: No such file or directory
# compilation terminated.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', 'g++ remove_duplicates.cpp -O2 -o dedup./dedup\n')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:2572, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2570 with self.builtin_trap:
#    2571     args = (magic_arg_s, cell)
# -> 2572     result = fn(*args, **kwargs)
#    2574 # The code below prevents the output from being displayed
#    2575 # when using magics with decorator @output_can_be_silenced
#    2576 # when the last Python token in the expression is a ';'.
#    2577 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\magics\script.py:160, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     158 else:
#     159     line = script
# --> 160 return self.shebang(line, cell)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\magics\script.py:348, in ScriptMagics.shebang(self, line, cell)
#     343 if args.raise_error and p.returncode != 0:
#     344     # If we get here and p.returncode is still None, we must have
#     345     # killed it but not yet seen its return code. We don't wait for it,
#     346     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     347     rc = p.returncode or -9
# --> 348     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'g++ remove_duplicates.cpp -O2 -o dedup./dedup\n'' returned non-zero exit status 1.

# %% [markdown]
# ### Complejidad
# - Tiempo: O(n), ya que se recorre el archivo una sola vez
# - Memoria: O(n), debido al almacenamiento de los identificadores unicos
#
# ### Resultado
# El archivo generado contiene unicamente transacciones unicas, manteniendo el orden original y conservando la primera aparicion.
